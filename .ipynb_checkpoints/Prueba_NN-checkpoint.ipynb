# %%
from tensorflow.keras.layers import Conv2D,Input,MaxPooling2D,Dropout,Flatten,Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import pandas as pd
from PIL import Image

def preprocess(im):
    
    im = im/255
    im -= .5
    return im


def load_image_batch(ids, batch_size=32):
    
    image_batch = np.zeros((batch_size, im_size, im_size, channel))
    
    label_hour = np.zeros((batch_size, 1))
    label_min = np.zeros((batch_size, 1))
    batch_ids = np.random.choice(ids, batch_size)
    
    ind = 0
    for i in range(len(batch_ids)):
        
        if channel == 1:
            im = Image.open(path + str(batch_ids[i]) + '.jpg').convert('L')
        else:
            im = Image.open(path + str(batch_ids[i]) + '.jpg')
        im = im.resize((im_size,im_size), Image.ANTIALIAS)
        im = np.array(im)
        image_batch[ind] = preprocess(im).reshape((im_size, im_size, channel))
        label_hour[ind] = (data['hour'][data.index==batch_ids[i]])
        label_min[ind] = (data['minute'][data.index==batch_ids[i]])/60
        ind += 1
            
    return (np.array(image_batch), np.array(label_hour), np.array(label_min))



inp = Input(shape=(100, 100, 1))
# Convolutional Layers
x = Conv2D(50, kernel_size=5, strides=2, activation='relu')(inp)
x = MaxPooling2D(pool_size=(2, 2), strides=2)(x)
x = Conv2D(100, kernel_size=3, strides=1, activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(150, kernel_size=3, strides=1, activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(200, kernel_size=3, strides=1, activation='relu')(x)
x = Dropout(.4)(x)
x = Flatten()(x)

# Hour branch
hour = Dense(144, activation='relu')(x)
hour = Dense(12, activation='softmax', name='hour')(hour)

# Minute Branch
minute = Dense(100, activation='relu')(x)
minute = Dense(1, activation='linear', name='minute')(minute)

model = Model(inputs=inp, outputs=[hour, minute])
optimizer = Adam(lr=0.001, clipnorm=0.001)
model.compile(loss=['sparse_categorical_crossentropy', 'mse'], optimizer=optimizer, metrics=['accuracy', 'mae'])

# %%
data = pd.read_csv('analog_clocks/label.csv')

channel = 1
im_size = 100
path = 'analog_clocks/images/'

train_ids = np.arange(10000)
test_ids = np.arange(500) + len(train_ids)

x_train, y1_train, y2_train = load_image_batch(train_ids, len(train_ids))

x_test, y1_test, y2_test = load_image_batch(test_ids, len(train_ids))

# %%
print('# Fit model on training data')
history = model.fit(x_train, [y1_train, y2_train],
                    batch_size=64,
                    epochs=50,
                    # We pass some validation for
                    # monitoring validation loss and metrics
                    # at the end of each epoch
                    validation_data=(x_test, [y1_test, y2_test]))

print('\nhistory dict:', history.history)
# Out:
# # Fit model on training data
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/50
# 10000/10000 [==============================] - 46s 5ms/sample - loss: 2.5785 - hour_loss: 2.4855 - minute_loss: 0.0932 - hour_accuracy: 0.0872 - hour_mae: 5.4546 - minute_accuracy: 0.0112 - minute_mae: 0.2590 - val_loss: 2.5691 - val_hour_loss: 2.4873 - val_minute_loss: 0.0821 - val_hour_accuracy: 0.0685 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0163 - val_minute_mae: 0.2466
# Epoch 2/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 2.3524 - hour_loss: 2.2716 - minute_loss: 0.0781 - hour_accuracy: 0.1824 - hour_mae: 5.4546 - minute_accuracy: 0.0097 - minute_mae: 0.2321 - val_loss: 1.8150 - val_hour_loss: 1.7444 - val_minute_loss: 0.0716 - val_hour_accuracy: 0.3518 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.2180
# Epoch 3/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 1.4138 - hour_loss: 1.3376 - minute_loss: 0.0756 - hour_accuracy: 0.4983 - hour_mae: 5.4546 - minute_accuracy: 0.0103 - minute_mae: 0.2249 - val_loss: 1.0286 - val_hour_loss: 0.9602 - val_minute_loss: 0.0694 - val_hour_accuracy: 0.6634 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0085 - val_minute_mae: 0.2150
# Epoch 4/50
# 10000/10000 [==============================] - 41s 4ms/sample - loss: 0.8722 - hour_loss: 0.8049 - minute_loss: 0.0673 - hour_accuracy: 0.6966 - hour_mae: 5.4546 - minute_accuracy: 0.0110 - minute_mae: 0.2111 - val_loss: 0.7348 - val_hour_loss: 0.6643 - val_minute_loss: 0.0740 - val_hour_accuracy: 0.7736 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0175 - val_minute_mae: 0.2246
# Epoch 5/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 0.5839 - hour_loss: 0.5249 - minute_loss: 0.0592 - hour_accuracy: 0.8091 - hour_mae: 5.4546 - minute_accuracy: 0.0120 - minute_mae: 0.1959 - val_loss: 0.6056 - val_hour_loss: 0.5477 - val_minute_loss: 0.0601 - val_hour_accuracy: 0.8105 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.1959
# Epoch 6/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 0.4131 - hour_loss: 0.3608 - minute_loss: 0.0523 - hour_accuracy: 0.8718 - hour_mae: 5.4546 - minute_accuracy: 0.0123 - minute_mae: 0.1823 - val_loss: 0.4505 - val_hour_loss: 0.3993 - val_minute_loss: 0.0528 - val_hour_accuracy: 0.8437 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0125 - val_minute_mae: 0.1803
# Epoch 7/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 0.3129 - hour_loss: 0.2657 - minute_loss: 0.0463 - hour_accuracy: 0.9099 - hour_mae: 5.4546 - minute_accuracy: 0.0133 - minute_mae: 0.1698 - val_loss: 0.4394 - val_hour_loss: 0.3931 - val_minute_loss: 0.0478 - val_hour_accuracy: 0.8633 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.1691
# Epoch 8/50
# 10000/10000 [==============================] - 38s 4ms/sample - loss: 0.2563 - hour_loss: 0.2159 - minute_loss: 0.0410 - hour_accuracy: 0.9258 - hour_mae: 5.4546 - minute_accuracy: 0.0142 - minute_mae: 0.1588 - val_loss: 0.3517 - val_hour_loss: 0.3091 - val_minute_loss: 0.0440 - val_hour_accuracy: 0.8811 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.1616
# Epoch 9/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 0.1950 - hour_loss: 0.1567 - minute_loss: 0.0377 - hour_accuracy: 0.9470 - hour_mae: 5.4546 - minute_accuracy: 0.0139 - minute_mae: 0.1517 - val_loss: 0.3738 - val_hour_loss: 0.3351 - val_minute_loss: 0.0414 - val_hour_accuracy: 0.8912 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0141 - val_minute_mae: 0.1534
# Epoch 10/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 0
- val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.1374
# Epoch 18/50
# 10000/10000 [==============================] - 44s 4ms/sample - loss: 0.0619 - hour_loss: 0.0389 - minute_loss: 0.0228 - hour_accuracy: 0.9879 - hour_mae: 5.4546 - minute_accuracy: 0.0155 - minute_mae: 0.1160 - val_loss: 0.3543 - val_hour_loss: 0.3251 - val_minute_loss: 0.0310 - val_hour_accuracy: 0.9126 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.1295
# Epoch 19/50
# 10000/10000 [==============================] - 40s 4ms/sample - loss: 0.0795 - hour_loss: 0.0547 - minute_loss: 0.0250 - hour_accuracy: 0.9824 - hour_mae: 5.4546 - minute_accuracy: 0.0153 - minute_mae: 0.1220 - val_loss: 0.2885 - val_hour_loss: 0.2601 - val_minute_loss: 0.0314 - val_hour_accuracy: 0.9161 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0160 - val_minute_mae: 0.1331
# Epoch 20/50
# 10000/10000 [==============================] - 39s 4ms/sample - loss: 0.0850 - hour_loss: 0.0615 - minute_loss: 0.0234 - hour_accuracy: 0.9786 - hour_mae: 5.4546 - minute_accuracy: 0.0154 - minute_mae: 0.1182 - val_loss: 0.3827 - val_hour_loss: 0.3494 - val_minute_loss: 0.0345 - val_hour_accuracy: 0.8960 - val_hour_mae: 5.3815 - val_minute_accuracy: 0.0175 - val_minute_mae: 0.1361
# Epoch 21/50
#  3200/10000 [========>.....................] - ETA: 22s - loss: 0.0796 - hour_loss: 0.0562 - minute_loss: 0.0235 - hour_accuracy: 0.9844 - hour_mae: 5.3847 - minute_accuracy: 0.0147 - minute_mae: 0.1189
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fcb3ee39e504> in <module>
#       6                     # monitoring validation loss and metrics
#       7                     # at the end of each epoch
# ----> 8                     validation_data=(x_test, [y1_test, y2_test]))
#       9
#      10 print('\nhistory dict:', history.history)
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/new/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy
# load pima indians dataset

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['hour_accuracy'])
plt.plot(history.history['val_hour_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for accuracy
plt.plot(history.history['minute_accuracy'])
plt.plot(history.history['val_minute_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for accuracy
plt.plot(history.history['hour_mae'])
plt.plot(history.history['val_hour_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for accuracy
plt.plot(history.history['minute_mae'])
plt.plot(history.history['val_minute_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6c463551e588> in <module>
#       3 # load pima indians dataset
#       4
# ----> 5 print(history.history.keys())
#       6 # summarize history for accuracy
#       7 plt.plot(history.history['hour_accuracy'])
#
# NameError: name 'history' is not defined

# %%
I = load_image_batch(2002, 1)
I[1:]
# Out:
# (array([[4.]]), array([[0.33333333]]))

# %%
print(np.argmax(model.predict(I[0])[0]))
model.predict(I[0])[1]
# Out:
# 4
# array([[0.238889]], dtype=float32)

# %%
plt.imshow(I[0][0,:,:,0])

# %%
import cv2
I = cv2.imread('barometro.jpg')
I = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)
I = cv2.resize(I, (100,100))
I = np.expand_dims(I, axis=0)
I = np.expand_dims(I, axis=3)
I.shape
